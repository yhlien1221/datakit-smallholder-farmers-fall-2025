# %% [markdown]
# # data import

# %%
import pandas as pd

# %%
wefarm = pd.read_csv(r"https://producersdirect-backups.s3.eu-west-1.amazonaws.com/athena-results/Unsaved/2025/09/26/b0cd514b-b9cc-4972-a0c2-c91726e6d825.csv")

# %% [markdown]
# # peek at the data

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 50)

wefarm.head(5)
# Out:
#    question_id  question_user_id question_language  \
# 0      3849056            519124               nyn
# 1      3849061            521327               eng
# 2      3849077            307821               nyn
# 3      3849077            307821               nyn
# 4      3849077            307821               nyn
#
#                                     question_content question_topic  \
# 0       E ABA WEFARM OFFICES ZABO NIZISHANGWA NKAHI?            NaN
# 1  Q this goes to wefarm. is it possible to get f...            NaN
# 2  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...         cattle
# 3  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...         cattle
# 4  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...            cat
#
#             question_sent  response_id  response_user_id response_language  \
# 0  2017-11-22 12:25:03+00     20691011            200868               nyn
# 1  2017-11-22 12:25:05+00      4334249            526113               eng
# 2  2017-11-22 12:25:08+00      3849291            296187               nyn
# 3  2017-11-22 12:25:08+00      3849291            296187               nyn
# 4  2017-11-22 12:25:08+00      3849291            296187               nyn
#
#                                     response_content response_topic  \
# 0                         E!23 Omubazi Ni Dudu Cipa'            NaN
# 1          Q1 which stage is marleks last vaccinated            NaN
# 2  Muhanguzi.Benon kuruga masha isingiro ente yaw...         tomato
# 3  Muhanguzi.Benon kuruga masha isingiro ente yaw...         cattle
# 4  Muhanguzi.Benon kuruga masha isingiro ente yaw...         tomato
#
#                    response_sent question_user_type question_user_status  \
# 0  2019-01-24 17:54:06.216221+00             farmer                 live
# 1         2018-01-04 08:57:28+00             farmer                 live
# 2         2017-11-22 12:35:26+00             farmer               zombie
# 3         2017-11-22 12:35:26+00             farmer               zombie
# 4         2017-11-22 12:35:26+00             farmer               zombie
#
#   question_user_country_code question_user_gender question_user_dob  \
# 0                         ug                  NaN               NaN
# 1                         ug                  NaN               NaN
# 2                         ug                  NaN               NaN
# 3                         ug                  NaN               NaN
# 4                         ug                  NaN               NaN
#
#   question_user_created_at response_user_type response_user_status  \
# 0   2017-11-18 13:09:11+00             farmer                 live
# 1   2017-11-20 11:55:48+00             farmer               zombie
# 2   2017-08-22 14:51:07+00             farmer               zombie
# 3   2017-08-22 14:51:07+00             farmer               zombie
# 4   2017-08-22 14:51:07+00             farmer               zombie
#
#   response_user_country_code response_user_gender response_user_dob  \
# 0                         ug                  NaN               NaN
# 1                         ug                  NaN               NaN
# 2                         ug                  NaN               NaN
# 3                         ug                  NaN               NaN
# 4                         ug                  NaN               NaN
#
#   response_user_created_at
# 0   2017-05-09 09:19:33+00
# 1   2017-11-22 10:13:03+00
# 2   2017-08-12 09:30:33+00
# 3   2017-08-12 09:30:33+00
# 4   2017-08-12 09:30:33+00

# %%
wefarm.shape
# Out:
# (20304843, 24)

# %% [markdown]
# # install libraries

# %% [markdown]
# # create dataframes by language

# %%
wefarm_eng_df = wefarm[wefarm["question_language"] == "eng"][["question_id", "question_content"]].drop_duplicates()

# %%
doc_lst = wefarm_eng_df["question_content"]

# %% [markdown]
# # install preprocessing libraries libraries

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.1)

# %%
import nltk
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
from gensim.utils import simple_preprocess
from tqdm import tqdm

# %% [markdown]
# #preprocessing

# %%
lem = WordNetLemmatizer()

def preprocess_text(text):
  tokens = simple_preprocess(text, deacc=True)
  return [lem.lemmatize(word, pos='v') for word in tokens]

# %%
processed_questions_eng_lst = []
for question in tqdm(doc_lst):
  processed_questions_eng_lst.append(preprocess_text(question))
# Out:
# 100%|██████████| 2940542/2940542 [01:46<00:00, 27591.10it/s]

# %% [markdown]
# # keyword extraction

# %% [markdown]
# ## definition

# %%
# keywords manually extracted from previous LDA analysis

market_keywords_lst = [
  "price",
  "sell",
  "market",
  "buy",
  "cost",
  "fee"
]


crop_keywords_lst = [
  "soil",
  "fruit",
  "plant",
  "leave",
  "fertilizer",
  "seed",
  "potatoes",
  "passion",
  "maize",
  "tomatoes",
  "banana",
  "manure",
  "layer",
  "coffee",
  "onions",
  "grow",
  "mulch",
  "bean",
  "type",
  "cabbage",
  "land",
  "variety",
  "yield",
  "keep",
  "rice",
  "harvest",
]

seasonality_keywords_lst = [
  "season",
  "time",
]

disease_keywords_lst = [
  "disease",
  "medicine",
  "treat",
  "weed",
  "control",
  "plant",
  "leave",
  "spray",
  "harvest",
  "affect",
  "prevent",
  "pests",
  "chemical",
  "rabbit",
  "care",
  "tick",
  "attack",
  "mean",
  "black",
  "space",
  "turn",
  "keep"
]

livestock_keywords_lst = [
  "animals",
  "pig",
  "cow",
  "goat",
  "hen",
  "chicken",
  "poultry",
  "lay",
  "egg",
  "milk",
  "breed",
  "dairy",
]

# %% [markdown]
# ## extrapolation

# %%
# %%time

from gensim.models import Word2Vec
w2v_model = Word2Vec(processed_questions_eng_lst, min_count=1, vector_size=100)
# Out:
# CPU times: user 3min 12s, sys: 751 ms, total: 3min 13s
# Wall time: 1min 9s

# %%
def run_w2v_broad(keyword_lst, top_n=50):
  full_keyword_lst = []
  for word in keyword_lst:
    full_keyword_lst.extend([w for w, s in w2v_model.wv.most_similar(word, topn=top_n)])
  return full_keyword_lst

# %%
def run_w2v_niche(keyword_lst, top_n=50):
  niche_keyword_dct = {}
  for word in keyword_lst:
    niche_keyword_dct[word] =[w for w, s in w2v_model.wv.most_similar(word, topn=top_n)]
  return niche_keyword_dct

# %%
# %%time

market_keywords_full_lst = run_w2v_broad(market_keywords_lst)
crop_keywords_full_lst = run_w2v_broad(crop_keywords_lst)
seasonality_keywords_full_lst = run_w2v_broad(seasonality_keywords_lst)
disease_keywords_full_lst = run_w2v_broad(disease_keywords_lst)
livestock_keywords_full_lst = run_w2v_broad(livestock_keywords_lst)
# Out:
# CPU times: user 3.12 s, sys: 5.68 ms, total: 3.12 s
# Wall time: 154 ms

# %%
# %%time

market_keywords_niche_dct = run_w2v_niche(market_keywords_lst)
crop_keywords_niche_dct = run_w2v_niche(crop_keywords_lst)
seasonality_keywords_niche_dct = run_w2v_niche(seasonality_keywords_lst)
disease_keywords_niche_dct = run_w2v_niche(disease_keywords_lst)
livestock_keywords_niche_dct = run_w2v_niche(livestock_keywords_lst)
# Out:
# CPU times: user 2.77 s, sys: 0 ns, total: 2.77 s
# Wall time: 116 ms

# %%
niche_category_dct = {
  "market": market_keywords_niche_dct,
  "crop": crop_keywords_niche_dct,
  "seasonality": seasonality_keywords_niche_dct,
  "disease": disease_keywords_niche_dct,
  "livestock": livestock_keywords_niche_dct
}

# %%
broad_category_dct = {
    "market": market_keywords_full_lst,
    "crop": crop_keywords_full_lst,
    "seasonality": seasonality_keywords_full_lst,
    "disease": disease_keywords_full_lst,
    "livestock": livestock_keywords_full_lst
}

# %% [markdown]
# # text categorization

# %% [markdown]
# ## niche keywords

# %%
def find_niche_keywords(doc):
  doc_words = set(doc)
  matches_dct = {}
  for category, sub_dct in niche_category_dct.items():
    for sub_category, keywords in sub_dct.items():
      if any(keyword in doc_words for keyword in keywords):
        matches_dct[f"{category}_{sub_category}"] = 1
  return matches_dct

# %%
niche_res_lst = []

for doc in tqdm(processed_questions_eng_lst):
  matches_dct = find_niche_keywords(doc)
  niche_res_lst.append(matches_dct)
# Out:
# 100%|██████████| 2940542/2940542 [07:01<00:00, 6980.81it/s]

# %%
# %%time

niche_res_df = pd.DataFrame(niche_res_lst)
# Out:
# CPU times: user 12.5 s, sys: 1e+03 ms, total: 13.5 s
# Wall time: 13.5 s

# %%
joined_niche_questions_eng_lst = [" ".join(doc) for doc in processed_questions_eng_lst]
niche_questions_eng_df = pd.DataFrame({
  "preprocessed_question": joined_niche_questions_eng_lst
})

# %%
niche_questions_id_eng_df = pd.concat([niche_questions_eng_df.reset_index(drop=True), wefarm_eng_df.reset_index(drop=True)], axis=1)
niche_questions_categories_df = pd.concat([niche_questions_id_eng_df, niche_res_df], axis=1)

# %%
niche_questions_categories_df.head(5)
# Out:
#                                preprocessed_question  question_id  \
# 0  this go to wefarm be it possible to get for us...      3849061
# 1  have stock rabbit urine for weeks mashambani s...      3849084
# 2  have mi can start aproject of poutry how can d...      3849098
# 3                       where do get seed of coconut      3849100
# 4                             which plant have omega      3849129
#
#                                     question_content  market_price  \
# 0  Q this goes to wefarm. is it possible to get f...           1.0
# 1  Q-i have stock rabbit's urine for 5 weeks mash...           NaN
# 2  Q J Have Mi 10000 Can J Start Aproject Of Pout...           NaN
# 3                   WHERE DO I GET SEEDS OF COCONUT?           NaN
# 4                         Q#.Which plant has omega3?           NaN
#
#    market_sell  market_buy  seasonality_time  livestock_animals  \
# 0          1.0         1.0               NaN                NaN
# 1          1.0         1.0               1.0                1.0
# 2          NaN         NaN               NaN                NaN
# 3          1.0         1.0               NaN                NaN
# 4          NaN         NaN               NaN                NaN
#
#    livestock_pig  livestock_cow  livestock_goat  livestock_hen  \
# 0            NaN            NaN             NaN            NaN
# 1            1.0            1.0             1.0            1.0
# 2            NaN            NaN             NaN            1.0
# 3            NaN            NaN             NaN            NaN
# 4            NaN            NaN             NaN            NaN
#
#    livestock_chicken  crop_layer  livestock_poultry  crop_plant  crop_variety  \
# 0                NaN         NaN                NaN         NaN           NaN
# 1                1.0         NaN                NaN         NaN           NaN
# 2                1.0         1.0                1.0         NaN           NaN
# 3                NaN         NaN                NaN         1.0           1.0
# 4                NaN         NaN                NaN         NaN           NaN
#
#    disease_plant  crop_seed  crop_grow  crop_mulch  crop_harvest  \
# 0            NaN        NaN        NaN         NaN           NaN
# 1            NaN        NaN        NaN         NaN           NaN
# 2            NaN        NaN        NaN         NaN           NaN
# 3            1.0        NaN        NaN         NaN           NaN
# 4            NaN        1.0        1.0         1.0           1.0
#
#    disease_harvest  crop_potatoes  crop_maize  crop_banana  crop_coffee  \
# 0              NaN            NaN         NaN          NaN          NaN
# 1              NaN            NaN         NaN          NaN          NaN
# 2              NaN            NaN         NaN          NaN          NaN
# 3              NaN            NaN         NaN          NaN          NaN
# 4              1.0            NaN         NaN          NaN          NaN
#
#    crop_onions  crop_bean  crop_cabbage  crop_land  crop_tomatoes  \
# 0          NaN        NaN           NaN        NaN            NaN
# 1          NaN        NaN           NaN        NaN            NaN
# 2          NaN        NaN           NaN        NaN            NaN
# 3          NaN        NaN           NaN        NaN            NaN
# 4          NaN        NaN           NaN        NaN            NaN
#
#    disease_disease  disease_care  crop_keep  disease_keep  market_market  \
# 0              NaN           NaN        NaN           NaN            NaN
# 1              NaN           NaN        NaN           NaN            NaN
# 2              NaN           NaN        NaN           NaN            NaN
# 3              NaN           NaN        NaN           NaN            NaN
# 4              NaN           NaN        NaN           NaN            NaN
#
#    market_cost  crop_rice  disease_rabbit  disease_treat  disease_prevent  \
# 0          NaN        NaN             NaN            NaN              NaN
# 1          NaN        NaN             NaN            NaN              NaN
# 2          NaN        NaN             NaN            NaN              NaN
# 3          NaN        NaN             NaN            NaN              NaN
# 4          NaN        NaN             NaN            NaN              NaN
#
#    disease_chemical  crop_fruit  livestock_milk  crop_leave  crop_passion  \
# 0               NaN         NaN             NaN         NaN           NaN
# 1               NaN         NaN             NaN         NaN           NaN
# 2               NaN         NaN             NaN         NaN           NaN
# 3               NaN         NaN             NaN         NaN           NaN
# 4               NaN         NaN             NaN         NaN           NaN
#
#    disease_leave  livestock_egg  livestock_breed  crop_fertilizer  \
# 0            NaN            NaN              NaN              NaN
# 1            NaN            NaN              NaN              NaN
# 2            NaN            NaN              NaN              NaN
# 3            NaN            NaN              NaN              NaN
# 4            NaN            NaN              NaN              NaN
#
#    crop_manure  seasonality_season  disease_control  crop_yield  \
# 0          NaN                 NaN              NaN         NaN
# 1          NaN                 NaN              NaN         NaN
# 2          NaN                 NaN              NaN         NaN
# 3          NaN                 NaN              NaN         NaN
# 4          NaN                 NaN              NaN         NaN
#
#    livestock_dairy  crop_soil  disease_spray  disease_turn  disease_attack  \
# 0              NaN        NaN            NaN           NaN             NaN
# 1              NaN        NaN            NaN           NaN             NaN
# 2              NaN        NaN            NaN           NaN             NaN
# 3              NaN        NaN            NaN           NaN             NaN
# 4              NaN        NaN            NaN           NaN             NaN
#
#    market_fee  crop_type  disease_medicine  disease_tick  disease_pests  \
# 0         NaN        NaN               NaN           NaN            NaN
# 1         NaN        NaN               NaN           NaN            NaN
# 2         NaN        NaN               NaN           NaN            NaN
# 3         NaN        NaN               NaN           NaN            NaN
# 4         NaN        NaN               NaN           NaN            NaN
#
#    livestock_lay  disease_weed  disease_black  disease_space  disease_affect  \
# 0            NaN           NaN            NaN            NaN             NaN
# 1            NaN           NaN            NaN            NaN             NaN
# 2            NaN           NaN            NaN            NaN             NaN
# 3            NaN           NaN            NaN            NaN             NaN
# 4            NaN           NaN            NaN            NaN             NaN
#
#    disease_mean
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
keyword_collst = niche_questions_categories_df.columns[3:]
keyword_sums = niche_questions_categories_df[keyword_collst].sum().sort_values()
sums_df = keyword_sums.reset_index()
sums_df.columns = ["col", "sum"]

sums_df["prefix"] = [c.split("_")[0] for c in sums_df["col"]]

sums_df = sums_df.sort_values(["prefix", "sum"], ascending=[True, False])

keyword_sums_dct = dict(zip(sums_df["col"], sums_df["sum"]))

# %%
import plotly.graph_objects as go

fig = go.Figure()

for k, v in keyword_sums_dct.items():
  fig.add_trace(
    go.Bar(
      x=[k],
      y=[v],
      marker={
        "color": [v],
        "colorscale": "greens"
      },
      name=k,
    )
  )

fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e8e75514-333b-4ba0-a75c-5b8aff923234" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8e75514-333b-4ba0-a75c-5b8aff923234")) {                    Plotly.newPlot(                        "e8e75514-333b-4ba0-a75c-5b8aff923234",                        [{"marker":{"color":[746650.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_bean","x":["crop_bean"],"y":[746650.0],"type":"bar"},{"marker":{"color":[667759.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_coffee","x":["crop_coffee"],"y":[667759.0],"type":"bar"},{"marker":{"color":[605833.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_maize","x":["crop_maize"],"y":[605833.0],"type":"bar"},{"marker":{"color":[596144.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_potatoes","x":["crop_potatoes"],"y":[596144.0],"type":"bar"},{"marker":{"color":[577149.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_banana","x":["crop_banana"],"y":[577149.0],"type":"bar"},{"marker":{"color":[576337.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_tomatoes","x":["crop_tomatoes"],"y":[576337.0],"type":"bar"},{"marker":{"color":[470987.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_seed","x":["crop_seed"],"y":[470987.0],"type":"bar"},{"marker":{"color":[464360.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_rice","x":["crop_rice"],"y":[464360.0],"type":"bar"},{"marker":{"color":[459328.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_mulch","x":["crop_mulch"],"y":[459328.0],"type":"bar"},{"marker":{"color":[438600.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop_grow","x":["crop_grow"],"y":[438600.0],"type":"bar"},{"marker":{"color":[409600.0],"colorscale":[[0.0 ...

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# niche_questions_categories_df.to_parquet("en_questions_cat_niche.parquet", index=False)
# !cp en_questions_cat_niche.parquet /content/drive/MyDrive/DataKit_WeFarm

# %% [markdown]
# ## broad keywords

# %%
def find_keywords(doc):
  doc_words = set(doc)
  matches_dct = {}
  for category, keywords in broad_category_dct.items():
    if any(keyword in doc_words for keyword in keywords):
      matches_dct[category] = 1
  return matches_dct

# %%
broad_res_lst = []

for doc in tqdm(processed_questions_eng_lst):
  matches_dct = find_keywords(doc)
  broad_res_lst.append(matches_dct)
# Out:
# 100%|██████████| 2940542/2940542 [03:46<00:00, 12979.67it/s]

# %%
broad_res_df = pd.DataFrame(broad_res_lst)

# %%
broad_joined_questions_eng_lst = [" ".join(doc) for doc in processed_questions_eng_lst]
broad_questions_eng_df = pd.DataFrame({
  "preprocessed_question": broad_joined_questions_eng_lst
})

# %%
broad_questions_id_eng_df = pd.concat([broad_questions_eng_df.reset_index(drop=True), wefarm_eng_df.reset_index(drop=True)], axis=1)
broad_questions_categories_df = pd.concat([broad_questions_id_eng_df, broad_res_df], axis=1)

# %%
broad_questions_categories_df.head(5)
# Out:
#                                preprocessed_question  question_id  \
# 0  this go to wefarm be it possible to get for us...      3849061
# 1  have stock rabbit urine for weeks mashambani s...      3849084
# 2  have mi can start aproject of poutry how can d...      3849098
# 3                       where do get seed of coconut      3849100
# 4                             which plant have omega      3849129
#
#                                     question_content  market  seasonality  \
# 0  Q this goes to wefarm. is it possible to get f...     1.0          NaN
# 1  Q-i have stock rabbit's urine for 5 weeks mash...     1.0          1.0
# 2  Q J Have Mi 10000 Can J Start Aproject Of Pout...     NaN          NaN
# 3                   WHERE DO I GET SEEDS OF COCONUT?     1.0          NaN
# 4                         Q#.Which plant has omega3?     NaN          NaN
#
#    livestock  crop  disease
# 0        NaN   NaN      NaN
# 1        1.0   NaN      NaN
# 2        1.0   1.0      NaN
# 3        NaN   1.0      1.0
# 4        NaN   1.0      1.0

# %%
sum_market = broad_questions_categories_df["market"].sum()
sum_livestock = broad_questions_categories_df["livestock"].sum()
sum_crop = broad_questions_categories_df["crop"].sum()
sum_disease = broad_questions_categories_df["disease"].sum()
sum_seasonality = broad_questions_categories_df["seasonality"].sum()

# %%
count_dct = {
  "market": sum_market,
  "livestock": sum_livestock,
  "crop": sum_crop,
  "disease": sum_disease,
  "seasonality": sum_seasonality,
  "nan": broad_questions_categories_df[["market", "disease", "crop", "seasonality", "livestock"]].isnull().all(axis=1).sum()
}

# %%
import plotly.graph_objects as go

fig = go.Figure()

for k, v in count_dct.items():
  fig.add_trace(
    go.Bar(
      x=[k],
      y=[v],
      marker={
        "color": [v],
        "colorscale": "greens"
      },
      name=k,
    )
  )

# %%
fig.update_layout({
  "title": "Reduced nulls from 1.6 million to 0.25 million"
})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6c3e5e3b-630c-4162-a5a9-08b493c36676" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c3e5e3b-630c-4162-a5a9-08b493c36676")) {                    Plotly.newPlot(                        "6c3e5e3b-630c-4162-a5a9-08b493c36676",                        [{"marker":{"color":[799504.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"market","x":["market"],"y":[799504.0],"type":"bar"},{"marker":{"color":[1055249.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"livestock","x":["livestock"],"y":[1055249.0],"type":"bar"},{"marker":{"color":[2000713.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"crop","x":["crop"],"y":[2000713.0],"type":"bar"},{"marker":{"color":[1886736.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"disease","x":["disease"],"y":[1886736.0],"type":"bar"},{"marker":{"color":[318284.0],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"seasonality","x":["seasonality"],"y":[318284.0],"type":"bar"},{"marker":{"color":[254539],"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]]},"name":"nan","x":["nan"],"y":[254539],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c1 ...

# %%
from plotly.subplots import make_subplots

bigfig = make_subplots(
  1, 6,
  specs=[[{'type': 'pie'}] * 6]
  )

for idx, (k, v) in enumerate(count_dct.items()):
  bigfig.add_trace(
    go.Pie(
      labels=[k, "not"],
      values=[v, len(broad_questions_categories_df) - v],
      marker={"colors": ["#D742A8", "#E7E7E7"]}
    ),
    row=1, col=idx+1
  )

bigfig.update_layout({
  "title": 'The majority of all questions concern "crops" and/or "disease"'
})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1e376e24-4367-4020-8c88-06132f00d565" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e376e24-4367-4020-8c88-06132f00d565")) {                    Plotly.newPlot(                        "1e376e24-4367-4020-8c88-06132f00d565",                        [{"labels":["market","not"],"marker":{"colors":["#D742A8","#E7E7E7"]},"values":[799504.0,2141038.0],"type":"pie","domain":{"x":[0.0,0.1388888888888889],"y":[0.0,1.0]}},{"labels":["livestock","not"],"marker":{"colors":["#D742A8","#E7E7E7"]},"values":[1055249.0,1885293.0],"type":"pie","domain":{"x":[0.17222222222222222,0.3111111111111111],"y":[0.0,1.0]}},{"labels":["crop","not"],"marker":{"colors":["#D742A8","#E7E7E7"]},"values":[2000713.0,939829.0],"type":"pie","domain":{"x":[0.34444444444444444,0.48333333333333334],"y":[0.0,1.0]}},{"labels":["disease","not"],"marker":{"colors":["#D742A8","#E7E7E7"]},"values":[1886736.0,1053806.0],"type":"pie","domain":{"x":[0.5166666666666667,0.6555555555555557],"y":[0.0,1.0]}},{"labels":["seasonality","not"],"marker":{"colors":["#D742A8","#E7E7E7"]},"values":[318284.0,2622258.0],"type":"pie","domain":{"x":[0.6888888888888889,0.8277777777777777],"y":[0.0,1.0]}},{"labels":["nan","not"],"marker":{"colors":["#D742A8","#E7E7E7"]},"values":[254539,2686003],"type":"pie","domain":{"x":[0.861111111111111,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777 ...

# %%
# broad_questions_categories_df.to_parquet("en_questions_cat_broad.parquet", index=False)
# !cp en_questions_cat_broad.parquet /content/drive/MyDrive/DataKit_WeFarm

# %%
# broad_questions_categories_df[["market", "disease", "crop", "seasonality", "livestock"]].isnull().all(axis=1).sum()
