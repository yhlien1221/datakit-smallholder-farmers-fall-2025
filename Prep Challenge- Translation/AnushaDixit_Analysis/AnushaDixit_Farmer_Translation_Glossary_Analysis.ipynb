# %% [markdown]
# # Prep Challenge: Bridging Languages - Translating Farmer Conversations

# %% [markdown]
# ### Data Loading

# %%
import pandas as pd

# %%
df_sample.to_csv("farmer.csv", index=False)

# %%
df=pd.read_csv("/content/farmer.csv")

# %%
df.head()
# Out:
#    question_id  question_user_id question_language  \
# 0      3849056            519124               nyn
# 1      3849061            521327               eng
# 2      3849077            307821               nyn
# 3      3849077            307821               nyn
# 4      3849077            307821               nyn
#
#                                     question_content question_topic  \
# 0       E ABA WEFARM OFFICES ZABO NIZISHANGWA NKAHI?            NaN
# 1  Q this goes to wefarm. is it possible to get f...            NaN
# 2  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...         cattle
# 3  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...         cattle
# 4  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...            cat
#
#             question_sent  response_id  response_user_id response_language  \
# 0  2017-11-22 12:25:03+00     20691011            200868               nyn
# 1  2017-11-22 12:25:05+00      4334249            526113               eng
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   question_id                 10000 non-null  int64
#  1   question_user_id            10000 non-null  int64
#  2   question_language           10000 non-null  object
#  3   question_content            10000 non-null  object
#  4   question_topic              9024 non-null   object
#  5   question_sent               10000 non-null  object
#  6   response_id                 10000 non-null  int64
#  7   response_user_id            10000 non-null  int64
#  8   response_language           10000 non-null  object
#  9   response_content            10000 non-null  object
#  10  response_topic              3763 non-null   object
#  11  response_sent               10000 non-null  object
#  12  question_user_type          10000 non-null  object
# ...

# %%
df.head()
# Out:
#    question_id  question_user_id question_language  \
# 0      3849056            519124               nyn
# 1      3849061            521327               eng
# 2      3849077            307821               nyn
# 3      3849077            307821               nyn
# 4      3849077            307821               nyn
#
#                                     question_content question_topic  \
# 0       E ABA WEFARM OFFICES ZABO NIZISHANGWA NKAHI?            NaN
# 1  Q this goes to wefarm. is it possible to get f...            NaN
# 2  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...         cattle
# 3  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...         cattle
# 4  E ENTE YANJE EZAIRE ENYENA YASHOBERA. \nOBWIRE...            cat
#
#             question_sent  response_id  response_user_id response_language  \
# 0  2017-11-22 12:25:03+00     20691011            200868               nyn
# 1  2017-11-22 12:25:05+00      4334249            526113               eng
# ...

# %% [markdown]
# ### Identify Languages

# %%
df['question_language'].value_counts()
# Out:
# question_language
# eng    5662
# nyn    2157
# swa    1992
# lug     189
# Name: count, dtype: int64

# %%
samples = df.groupby('question_language')['question_content'].apply(lambda x: x.sample(5, random_state=42))
print(samples)
# Out:
# question_language
# eng                9625    Which Type Of Onion Variety Does Best In Bungo...
#                    9068       Q IS POLLARD GOOD TO PIG WHEN IT HAS CHILDREN?
#                    6615    Q How much is a kg of beans and maize respecti...
#                    2710                 Q i need to know how to grow vanilla
#                    4836    Q How do we know that a banana is ready 2 be r...
# lug                8568    E Mweziki Omutufu Ogwokusimbilamu Enyanya? Nek...
#                    8046    E Kigimusa Ki Ekilungi Okusimbira Munyanya Nek...
#                    977     E# LUKENGE INNOCENT DAGALA KI RYE NKOZESA OKUF...
#                    704     E WEMBA NSIMBYE MERON  AYIINZA  OKUMERA  ERA N...
#                    3120    E KIKA KI EKY'OBUMONDE OMULIMI BW'ALIMA N'AFUN...
# nyn                2697    E NIMBUZA ENJOKI NIBAZIHA OMWEZI GWAKAINGAHA K...
#                    6661    E ninyenda okumanya empunu nezarira obwire bur...
# ...

# %%
import re

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"[^a-zA-Z0-9\s]", "", text)  # remove punctuation
    text = re.sub(r"\s+", " ", text).strip()
    return text

df['clean_question'] = df['question_content'].apply(clean_text)

# %% [markdown]
# ### Translate Texts

# %%
from transformers import pipeline

# %%
from tqdm import tqdm
tqdm.pandas()

# %%
# Translation pipelines
translator_lug = pipeline("translation", model="facebook/nllb-200-distilled-600M", src_lang="lug_Latn", tgt_lang="eng_Latn")
translator_swa = pipeline("translation", model="Helsinki-NLP/opus-mt-swc-en")
translator_nyn = pipeline("translation", model="facebook/nllb-200-distilled-600M", src_lang="nya_Latn", tgt_lang="eng_Latn")

# %%
# Step 1: Separate by language
langs = ['swa', 'lug', 'nyn']
batch_size = 10

# %%
for lang in langs:
    subset = df[df['question_language'] == lang]
    texts = subset['clean_question'].fillna('').tolist()

    # Pick translator
    if lang == 'swa':
        translator = translator_swa
    elif lang == 'lug':
        translator = translator_lug
    elif lang == 'nyn':
        translator = translator_nyn
    else:
        continue

    translated_texts = []

    for i in tqdm(range(0, len(texts), batch_size), desc=f"Translating {lang}"):
        batch = texts[i:i + batch_size]
        try:
            outputs = translator(batch)  # Call the pipeline directly
            translated_texts.extend([x['translation_text'] for x in outputs])
        except Exception as e:
            print(f"Error in batch {i}: {e}")
            translated_texts.extend(batch)  # keep original on failure

    # Assign translations back
    df.loc[df['question_language'] == lang, 'translated_en'] = translated_texts
# Out:
# ...
# Translating nyn: 100%|██████████| 216/216 [29:11<00:00,  8.11s/it]

# %%
df['translated_en'].head()
# Out:
# 0             e baba wefarm offices their are reported
# 1                                                  nan
# 2    In the same way, in the same way, in the same ...
# 3    In the same way, in the same way, in the same ...
# 4    In the same way, in the same way, in the same ...
# Name: translated_en, dtype: object

# %% [markdown]
# ### Handle English Rows

# %%
df['clean_question'] = df['clean_question'].astype(str)
df['translated_en'] = df['translated_en'].astype(str)

# %%
df['translated_en'] = df['translated_en'].replace(['nan', 'None', ''], pd.NA)
df['translated_en'] = df['translated_en'].fillna(df['clean_question'])

# %%
df.isna().sum()
# Out:
# question_id                      0
# question_user_id                 0
# question_language                0
# question_content                 0
# question_topic                 976
# question_sent                    0
# response_id                      0
# response_user_id                 0
# response_language                0
# response_content                 0
# response_topic                6237
# response_sent                    0
# question_user_type               0
# question_user_status             0
# question_user_country_code       0
# question_user_gender          9160
# question_user_dob             8917
# question_user_created_at         0
# response_user_type               0
# response_user_status             0
# response_user_country_code       0
# response_user_gender          8597
# response_user_dob             8044
# response_user_created_at         0
# clean_question                   0
# translated_en                    0
# dtype: int64

# %%
# Quick look at results
df[['question_language', 'clean_question', 'translated_en']].sample(20, random_state=42)
# Out:
#      question_language                                     clean_question  \
# 6252               eng               where can i get strawberry seedlings
# 4684               eng  q how long does it take for the pig to give bi...
# 1731               eng                   e why was price maize is too low
# 4742               swa  ngombe wangu rahisi anywe maji hata nikiweja c...
# 4521               eng     q if i buy a duck near my home can it fly back
# 6340               eng                   how can i improve my cattle farm
# 576                swa  s bona uki panda maidi mavuno yake nikidogo ma...
# 5202               eng  q how can banana plantation be maintained with...
# 6363               nyn  e nabaninyenda manye water meroni neyenra obwi...
# 439                swa  s kuna dawa ama mbinu yoyote ya kuzuia ndege w...
# 2750               nyn            ewefarm omuzano nigutandika orwakangahi
# 7487               swa        s mbuzi humaliza mwesi ngapi ndio ijifungue
# ...

# %%
df[df['question_language'] == 'lug'][['clean_question', 'translated_en']].head(10)
# Out:
#                                         clean_question  \
# 95     e edagala lino telikossa mukyelembuuza sulaiman
# 217  e emyanyi okukala obutabi dagala ki eriyinza o...
# 218  e emyanyi okukala obutabi dagala ki eriyinza o...
# 219  e emyanyi okukala obutabi dagala ki eriyinza o...
# 220  e emyanyi okukala obutabi dagala ki eriyinza o...
# 221  e emyanyi okukala obutabi dagala ki eriyinza o...
# 274       e nkozentya okukomya akauka akatulila kasoli
# 329  elumondeakurilaemweziemekaokumukungulajuliusmi...
# 330  elumondeakurilaemweziemekaokumukungulajuliusmi...
# 331  elumondeakurilaemweziemekaokumukungulajuliusmi...
#
#                                          translated_en
# 95                     e this drug will not affect you
# 217  e know how to be safe what medication can help...
# 218  e know how to be safe what medication can help...
# 219  e know how to be safe what medication can help...
# 220  e know how to be safe what medication can help...
# ...

# %%
df[df['question_language'] == 'nyn'][['clean_question', 'translated_en']].head(10)
# Out:
#                                        clean_question  \
# 0         e aba wefarm offices zabo nizishangwa nkahi
# 2   e ente yanje ezaire enyena yashobera obwire bw...
# 3   e ente yanje ezaire enyena yashobera obwire bw...
# 4   e ente yanje ezaire enyena yashobera obwire bw...
# 5   e ente yanje ezaire enyena yashobera obwire bw...
# 6   e radio ezimwagaba nituzituga tunta ariho abar...
# 35  e embibo ya watermeroni ndagyihahi ndi amos om...
# 36  e embibo ya watermeroni ndagyihahi ndi amos om...
# 37  e embibo ya watermeroni ndagyihahi ndi amos om...
# 42                                     eizina stephen
#
#                                         translated_en
# 0            e baba wefarm offices their are reported
# 2   In the same way, in the same way, in the same ...
# 3   In the same way, in the same way, in the same ...
# 4   In the same way, in the same way, in the same ...
# 5   In the same way, in the same way, in the same ...
# ...

# %%
df[df['question_language'] == 'swa'][['clean_question', 'translated_en']].head(10)
# Out:
#                                        clean_question  \
# 7                          s dawa ya virobotokwa kuku
# 8                          s dawa ya virobotokwa kuku
# 10                            s dawayavirobotokwakuku
# 11                            s dawayavirobotokwakuku
# 12                            s dawayavirobotokwakuku
# 13                            s dawayavirobotokwakuku
# 14                            s dawayavirobotokwakuku
# 22  qniko na pundaanakohoa ni dawa gany naexa mpea...
# 25  s ngombe aina kani itoayo maziwa 20 lita kwa siku
# 30  s niko na watu kumi hapa busia kwa sasa wanaul...
#
#                                         translated_en
# 7                                        U.S. chicken
# 8                                        U.S. chicken
# 10                                       syavkukukuku
# 11                                       syavkukukuku
# 12                                       syavkukukuku
# ...

# %%
df[df['question_language'] == 'eng'][['clean_question', 'translated_en']].head(10)
# Out:
#                                        clean_question  \
# 1   q this goes to wefarm is it possible to get fo...
# 9   qi have stock rabbits urine for 5 weeks masham...
# 15  q j have mi 10000 can j start aproject of pout...
# 16                    where do i get seeds of coconut
# 17                    where do i get seeds of coconut
# 18                    where do i get seeds of coconut
# 19                    where do i get seeds of coconut
# 20                    where do i get seeds of coconut
# 21                    where do i get seeds of coconut
# 23                            qwhich plant has omega3
#
#                                         translated_en
# 1   q this goes to wefarm is it possible to get fo...
# 9   qi have stock rabbits urine for 5 weeks masham...
# 15  q j have mi 10000 can j start aproject of pout...
# 16                    where do i get seeds of coconut
# 17                    where do i get seeds of coconut
# ...

# %% [markdown]
# ### Farmer Term Glossary

# %%
import re
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

custom_stopwords = {'q', 'e', 'im', 'get', 'going', 'got', 'want', 'like', 'one', 'much', 'many'}

stop_words = set(stopwords.words('english'))
all_stopwords = stop_words.union(custom_stopwords)

def clean_text(text):
    text = re.sub(r'[^a-zA-Z\s]', '', str(text))
    text = text.lower()
    words = [word for word in text.split() if word not in all_stopwords]
    return ' '.join(words)

df['translated_clean'] = df['translated_en'].apply(clean_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Keyword Frequency

# %%
from collections import Counter

words = " ".join(df['translated_clean']).split()
common_words = Counter(words).most_common(30)
print(common_words)
# Out:
# [('goat', 894), ('cat', 782), ('plant', 711), ('best', 569), ('use', 442), ('drink', 398), ('per', 397), ('buruduru', 384), ('give', 377), ('take', 331), ('market', 311), ('cow', 307), ('good', 300), ('price', 296), ('grow', 294), ('maize', 291), ('long', 290), ('chicken', 284), ('type', 276), ('start', 271), ('ambrose', 271), ('know', 261), ('farmer', 254), ('nigga', 248), ('eggs', 244), ('beans', 241), ('chicks', 233), ('medicine', 229), ('bathroom', 228), ('banana', 224)]

# %% [markdown]
# ### WordCloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df['translated_clean'])
wordcloud = WordCloud(width=1000, height=500, background_color='white').generate(text)

plt.figure(figsize=(12,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Extract top terms by frequency
top_terms = Counter(words).most_common(50)

glossary_df = pd.DataFrame(top_terms, columns=['Term', 'Frequency'])
glossary_df.head(10)
# Out:
#        Term  Frequency
# 0      goat        894
# 1       cat        782
# 2     plant        711
# 3      best        569
# 4       use        442
# 5     drink        398
# 6       per        397
# 7  buruduru        384
# 8      give        377
# 9      take        331

# %% [markdown]
# ### Topic Modeling

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

vectorizer = CountVectorizer(max_df=0.9, min_df=10, stop_words='english')
X = vectorizer.fit_transform(df['translated_clean'])

lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(X)

terms = vectorizer.get_feature_names_out()
for idx, topic in enumerate(lda.components_):
    print(f"\nTopic {idx+1}:")
    print([terms[i] for i in topic.argsort()[-10:]])
# Out:
# Topic 1:
# ['use', 'time', 'season', 'farmer', 'best', 'maize', 'grow', 'price', 'drink', 'plant']
#
# Topic 2:
# ['water', 'used', 'tomato', 'plant', 'build', 'little', 'control', 'planting', 'cow', 'way']
#
# Topic 3:
# ['drug', 'county', 'seeds', 'potatoes', 'month', 'farm', 'rain', 'answer', 'bathroom', 'use']
#
# Topic 4:
# ['milk', 'fish', 'tell', 'rabbits', 'goats', 'able', 'eggs', 'start', 'chicken', 'long']
#
# Topic 5:
# ['best', 'know', 'chicks', 'cabbage', 'shoot', 'waste', 'key', 'youre', 'cat', 'goat']

# %% [markdown]
# ### Keyword Frequency

# %%
from collections import Counter
import re

import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
custom_stopwords = {'going', 'get', 'got', 'im', 'want', 'make', 'take', 'need', 'does', 'one'}
all_stopwords = stop_words.union(custom_stopwords)

text_data = " ".join(df['translated_en'].dropna()).lower()
words = re.findall(r'\b[a-z]{4,}\b', text_data)

filtered_words = [w for w in words if w not in all_stopwords]

common_terms = Counter(filtered_words).most_common(30)
glossary_df = pd.DataFrame(common_terms, columns=['term', 'frequency'])
glossary_df.to_csv("farmer_glossary.csv", index=False)
glossary_df.head(10)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#        term  frequency
# 0      goat        900
# 1     plant        719
# 2      best        569
# 3      many        411
# 4     drink        398
# 5  buruduru        384
# 6      give        377
# 7      much        322
# 8    market        311
# 9      good        300

# %% [markdown]
# ### Cluster Analysis

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
X = vectorizer.fit_transform(df['translated_en'].dropna())

kmeans = KMeans(n_clusters=5, random_state=42)
df['topic_cluster'] = kmeans.fit_predict(X)

df[['translated_en', 'topic_cluster']].head(10)
# Out:
#                                        translated_en  topic_cluster
# 0           e baba wefarm offices their are reported              2
# 1  q this goes to wefarm is it possible to get fo...              2
# 2  In the same way, in the same way, in the same ...              2
# 3  In the same way, in the same way, in the same ...              2
# 4  In the same way, in the same way, in the same ...              2
# 5  In the same way, in the same way, in the same ...              2
# 6  e radio broadcasts we take out the existing st...              2
# 7                                       U.S. chicken              2
# 8                                       U.S. chicken              2
# 9  qi have stock rabbits urine for 5 weeks masham...              2
